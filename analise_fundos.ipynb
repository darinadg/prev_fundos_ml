# %%
import pandas as pd

df = pd.read_excel("Dados Darina.xlsx")

df.head()
# Out:
#       RESUMO DOS RESULTADOS Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                       NaN        NaN        NaN        NaN        NaN
# 1  Estatística de regressão        NaN        NaN        NaN        NaN
# 2                R múltiplo   0.996492        NaN        NaN        NaN
# 3                R-Quadrado   0.992997        NaN        NaN        NaN
# 4       R-quadrado ajustado   0.992823        NaN        NaN        NaN
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN

# %%
df = pd.read_excel("Dados TCP Darina2.xlsx")
df.head()
# Out:
#       RESUMO DOS RESULTADOS Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                       NaN        NaN        NaN        NaN        NaN
# 1  Estatística de regressão        NaN        NaN        NaN        NaN
# 2                R múltiplo   0.996492        NaN        NaN        NaN
# 3                R-Quadrado   0.992997        NaN        NaN        NaN
# 4       R-quadrado ajustado   0.992823        NaN        NaN        NaN
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN

# %%
df = pd.read_excel("Dados TCP Darina2.xlsx", skiprows=5)
df.head()
# Out:
#   R-quadrado ajustado 0.992823076896215 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0         Erro padrão      48964.831965        NaN        NaN        NaN
# 1         Observações               249        NaN        NaN        NaN
# 2                 NaN               NaN        NaN        NaN        NaN
# 3               ANOVA               NaN        NaN        NaN        NaN
# 4                 NaN                gl         SQ         MQ          F
#
#           Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0                NaN        NaN        NaN        NaN
# 1                NaN        NaN        NaN        NaN
# 2                NaN        NaN        NaN        NaN
# 3                NaN        NaN        NaN        NaN
# 4  F de significação        NaN        NaN        NaN

# %%
ipca = pd.read_excel("ipeadata[10-06-2015-03-35]INFLACAO.xls")
ipca.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12508\3595476420.py in <module>
# ----> 1 ipca = pd.read_excel("ipeadata[10-06-2015-03-35]INFLACAO.xls")
#       2 ipca.head()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     455     if not isinstance(io, ExcelFile):
#     456         should_close = True
# --> 457         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     458     elif engine and engine != io.engine:
#     459         raise ValueError(
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1374                 ext = "xls"
#    1375             else:
# -> 1376                 ext = inspect_excel_format(
#    1377                     content_or_path=path_or_buffer, storage_options=storage_options
#    1378                 )
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in inspect_excel_format(content_or_path, storage_options)
#    1248         content_or_path = BytesIO(content_or_path)
#    1249
# -> 1250     with get_handle(
#    1251         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1252     ) as handle:
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     793         else:
#     794             # Binary mode
# --> 795             handle = open(handle, ioargs.mode)
#     796         handles.append(handle)
#     797
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ipeadata[10-06-2015-03-35]INFLACAO.xls'

# %%
ipca = pd.read_excel("ipeadata[10-06-2015-03-35]INFLACAO.xls")
ipca.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12508\3595476420.py in <module>
# ----> 1 ipca = pd.read_excel("ipeadata[10-06-2015-03-35]INFLACAO.xls")
#       2 ipca.head()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     455     if not isinstance(io, ExcelFile):
#     456         should_close = True
# --> 457         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     458     elif engine and engine != io.engine:
#     459         raise ValueError(
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1374                 ext = "xls"
#    1375             else:
# -> 1376                 ext = inspect_excel_format(
#    1377                     content_or_path=path_or_buffer, storage_options=storage_options
#    1378                 )
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in inspect_excel_format(content_or_path, storage_options)
#    1248         content_or_path = BytesIO(content_or_path)
#    1249
# -> 1250     with get_handle(
#    1251         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1252     ) as handle:
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     793         else:
#     794             # Binary mode
# --> 795             handle = open(handle, ioargs.mode)
#     796         handles.append(handle)
#     797
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ipeadata[10-06-2015-03-35]INFLACAO.xls'

# %%
ipca = pd.read_excel("ipeadata[10-06-2015-03-35]INFLACAO.xls", skiprows=10)
ipca.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12508\1426166453.py in <module>
# ----> 1 ipca = pd.read_excel("ipeadata[10-06-2015-03-35]INFLACAO.xls", skiprows=10)
#       2 ipca.head()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     455     if not isinstance(io, ExcelFile):
#     456         should_close = True
# --> 457         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     458     elif engine and engine != io.engine:
#     459         raise ValueError(
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1374                 ext = "xls"
#    1375             else:
# -> 1376                 ext = inspect_excel_format(
#    1377                     content_or_path=path_or_buffer, storage_options=storage_options
#    1378                 )
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in inspect_excel_format(content_or_path, storage_options)
#    1248         content_or_path = BytesIO(content_or_path)
#    1249
# -> 1250     with get_handle(
#    1251         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1252     ) as handle:
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     793         else:
#     794             # Binary mode
# --> 795             handle = open(handle, ioargs.mode)
#     796         handles.append(handle)
#     797
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ipeadata[10-06-2015-03-35]INFLACAO.xls'

# %%
ipca = pd.read_excel("ipeadata[10-06-2015-03-35]INFLACAO.xls", skiprows=10)
ipca.head()
# Out:
#    1980.10  9.4805311984776
# 0  1980.11         6.673360
# 1  1980.12         6.614084
# 2  1981.01         6.837511
# 3  1981.02         6.401149
# 4  1981.03         4.971748

# %%
ipca.columns = ["data", "ipca"]
ipca.head()
# Out:
#       data      ipca
# 0  1980.11  6.673360
# 1  1980.12  6.614084
# 2  1981.01  6.837511
# 3  1981.02  6.401149
# 4  1981.03  4.971748

# %%
ipca["data"] = ipca["data"].astype(str)

ipca["ano"] = ipca["data"].str[:4]
ipca["mes"] = ipca["data"].str[5:]

ipca["data"] = ipca["ano"] + "-" + ipca["mes"] + "-01"

ipca["data"] = pd.to_datetime(ipca["data"])

ipca = ipca[["data", "ipca"]]

ipca.head()
# Out:
#         data      ipca
# 0 1980-11-01  6.673360
# 1 1980-12-01  6.614084
# 2 1981-01-01  6.837511
# 3 1981-02-01  6.401149
# 4 1981-03-01  4.971748

# %%
selic = pd.read_excel("ipeadata[10-06-2015-03-39]TAXAJUROS-SELIC.xls", skiprows=10)

selic.columns = ["data", "selic"]

# converter direto para data
selic["data"] = pd.to_datetime(selic["data"], dayfirst=True)

selic.head()
# Out:
#         data    selic
# 0 1996-07-11  25.3401
# 1 1996-07-12  25.3401
# 2 1996-07-13  25.3401
# 3 1996-07-14  25.3401
# 4 1996-07-15  25.3401

# %%
pib = pd.read_excel("ipeadata[10-06-2015-03-55]PIB-90-4.15.xls", skiprows=10)

pib.columns = ["data", "pib"]

# transformar em string
pib["data"] = pib["data"].astype(str)

# separar ano e período
pib["ano"] = pib["data"].str[:4]
pib["periodo"] = pib["data"].str[5:]

# transformar período em mês (aproximação)
# 1 -> jan, 2 -> abr, 3 -> jul, 4 -> out
mapa = {
    "01": "01",
    "02": "04",
    "03": "07",
    "04": "10"
}

pib["mes"] = pib["periodo"].map(mapa)

# criar data
pib["data"] = pib["ano"] + "-" + pib["mes"] + "-01"
pib["data"] = pd.to_datetime(pib["data"])

# manter colunas finais
pib = pib[["data", "pib"]]

pib = pib.dropna()
pib.head()
# Out:
#          data   pib
# 2  1991-01-01   2.1
# 3  1991-04-01   2.4
# 4  1991-07-01   2.5
# 5  1991-10-01   3.1
# 14 1992-01-01  13.1

# %%
poupanca = pd.read_excel("ipeadata[10-06-2015-03-Poup.Nac.Bruta 91-14 trimestral.xls", skiprows=10)

poupanca.columns = ["data", "poupanca"]

# transformar em string
poupanca["data"] = poupanca["data"].astype(str)

# separar ano e trimestre
poupanca["ano"] = poupanca["data"].str[:4]
poupanca["trimestre"] = poupanca["data"].str[-2:]  # pega T1, T2...

# mapa correto
mapa = {
    "T1": "01",
    "T2": "04",
    "T3": "07",
    "T4": "10"
}

poupanca["mes"] = poupanca["trimestre"].map(mapa)

# criar data
poupanca["data"] = poupanca["ano"] + "-" + poupanca["mes"] + "-01"
poupanca["data"] = pd.to_datetime(poupanca["data"])

# manter colunas finais
poupanca = poupanca[["data", "poupanca"]]

# remover possíveis erros
poupanca = poupanca.dropna()

poupanca.head()
# Out:
#         data      poupanca
# 0 1993-07-01    764.918923
# 1 1993-10-01   1620.964035
# 2 1994-01-01    876.760450
# 3 1994-04-01  10562.670166
# 4 1994-07-01  35070.481617

# %%
# SELIC mensal
selic["data"] = selic["data"].dt.to_period("M").dt.to_timestamp()

selic_mensal = selic.groupby("data")["selic"].mean().reset_index()

# PIB mensal
pib_mensal = pib.set_index("data").resample("M").ffill().reset_index()

# POUPANÇA mensal
poupanca_mensal = poupanca.set_index("data").resample("M").ffill().reset_index()

# IPCA já mensal
ipca_mensal = ipca.copy()

# juntar tudo
df_final = ipca_mensal.merge(selic_mensal, on="data") \
                     .merge(pib_mensal, on="data") \
                     .merge(poupanca_mensal, on="data")

df_final.head()
# Out:
# Empty DataFrame
# Columns: [ipca, selic, pib, data, poupanca]
# Index: []

# %%
df_final.shape
# Out:
# (0, 5)

# %%
df_final = ipca_mensal.copy()

# %%
df_final = df_final.merge(selic_mensal, on="data", how="left")
df_final = df_final.merge(pib_mensal, on="data", how="left")
df_final = df_final.merge(poupanca_mensal, on="data", how="left")

df_final.head()
# Out:
#         data      ipca  selic  pib  poupanca
# 0 1980-11-01  6.673360    NaN  NaN       NaN
# 1 1980-12-01  6.614084    NaN  NaN       NaN
# 2 1981-01-01  6.837511    NaN  NaN       NaN
# 3 1981-02-01  6.401149    NaN  NaN       NaN
# 4 1981-03-01  4.971748    NaN  NaN       NaN

# %%
df_final = df_final[df_final["data"] >= "1996-01-01"]

# %%
df_final = df_final.fillna(method="ffill")

# %%
df_final = df_final.dropna()

# %%
df_final.head()
df_final.shape
# Out:
# (0, 5)

# %%
print("IPCA:", ipca_mensal["data"].min())
print("SELIC:", selic_mensal["data"].min())
print("PIB:", pib_mensal["data"].min())
print("POUPANÇA:", poupanca_mensal["data"].min())
# Out:
# IPCA: 1980-11-01 00:00:00
# SELIC: 1996-07-01 00:00:00
# PIB: 1991-01-31 00:00:00
# POUPANÇA: 1993-07-31 00:00:00

# %%
data_inicio = max(
    ipca_mensal["data"].min(),
    selic_mensal["data"].min(),
    pib_mensal["data"].min(),
    poupanca_mensal["data"].min()
)

df_final = df_final[df_final["data"] >= data_inicio]

df_final = df_final.fillna(method="ffill")
df_final = df_final.dropna()

df_final.head()
df_final.shape
# Out:
# (0, 5)

# %%
df_final = df_final[df_final["data"] >= data_inicio]

df_final.head()
# Out:
# Empty DataFrame
# Columns: [data, ipca, selic, pib, poupanca]
# Index: []

# %%
df_final.isna().sum()
# Out:
# data        0.0
# ipca        0.0
# selic       0.0
# pib         0.0
# poupanca    0.0
# dtype: float64

# %%
df_final = df_final.fillna(method="ffill")
df_final = df_final.fillna(method="bfill")

# %%
df_final = df_final.dropna()

# %%
df_final.shape
df_final.head()
# Out:
# Empty DataFrame
# Columns: [data, ipca, selic, pib, poupanca]
# Index: []

# %%
df_final.shape
# Out:
# (0, 5)

# %%
ipca_mensal["data"] = ipca_mensal["data"].dt.to_period("M").dt.to_timestamp("M")
selic_mensal["data"] = selic_mensal["data"].dt.to_period("M").dt.to_timestamp("M")
pib_mensal["data"] = pib_mensal["data"].dt.to_period("M").dt.to_timestamp("M")
poupanca_mensal["data"] = poupanca_mensal["data"].dt.to_period("M").dt.to_timestamp("M")

# %%
df_final = ipca_mensal.copy()

df_final = df_final.merge(selic_mensal, on="data", how="left")
df_final = df_final.merge(pib_mensal, on="data", how="left")
df_final = df_final.merge(poupanca_mensal, on="data", how="left")

df_final.head()
# Out:
#         data      ipca  selic  pib  poupanca
# 0 1980-11-30  6.673360    NaN  NaN       NaN
# 1 1980-12-31  6.614084    NaN  NaN       NaN
# 2 1981-01-31  6.837511    NaN  NaN       NaN
# 3 1981-02-28  6.401149    NaN  NaN       NaN
# 4 1981-03-31  4.971748    NaN  NaN       NaN

# %%
data_inicio = max(
    ipca_mensal["data"].min(),
    selic_mensal["data"].min(),
    pib_mensal["data"].min(),
    poupanca_mensal["data"].min()
)

df_final = df_final[df_final["data"] >= data_inicio]

# %%
df_final = df_final.fillna(method="ffill")
df_final = df_final.fillna(method="bfill")

# %%
df_final.shape
df_final.head()
# Out:
#           data  ipca    selic      pib      poupanca
# 188 1996-07-31  1.11  25.3401  63248.4  31776.160083
# 189 1996-08-31  0.44  25.3401  63248.4  31776.160083
# 190 1996-09-30  0.15  25.0453  63248.4  31776.160083
# 192 1996-11-30  0.32  23.5803  64347.8  39791.088410
# 193 1996-12-31  0.47  22.9988  64347.8  39791.088410

# %%
df_final.shape
# Out:
# (226, 5)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(df_final["data"], df_final["ipca"], label="IPCA")
plt.plot(df_final["data"], df_final["selic"], label="SELIC")
plt.legend()
plt.title("IPCA vs SELIC")
plt.show()

# %%
df_final.corr()
# Out:
#               ipca     selic       pib  poupanca
# ipca      1.000000  0.116308  0.001425 -0.113436
# selic     0.116308  1.000000 -0.754351 -0.781931
# pib       0.001425 -0.754351  1.000000  0.911494
# poupanca -0.113436 -0.781931  0.911494  1.000000

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X = df_final[["selic", "pib", "poupanca"]]
y = df_final["ipca"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

modelo = LinearRegression()
modelo.fit(X_train, y_train)

modelo.score(X_test, y_test)
# Out:
# -0.013495076087813418

# %%
df_final.corr()
# Out:
#               ipca     selic       pib  poupanca
# ipca      1.000000  0.116308  0.001425 -0.113436
# selic     0.116308  1.000000 -0.754351 -0.781931
# pib       0.001425 -0.754351  1.000000  0.911494
# poupanca -0.113436 -0.781931  0.911494  1.000000

# %%
df_final["selic_lag1"] = df_final["selic"].shift(1)
df_final["selic_lag3"] = df_final["selic"].shift(3)

df_final = df_final.dropna()

df_final.corr()
# Out:
#                 ipca     selic       pib  poupanca  selic_lag1  selic_lag3
# ipca        1.000000  0.116185  0.003445 -0.113406    0.056608    0.013198
# selic       0.116185  1.000000 -0.748754 -0.776432    0.884278    0.798559
# pib         0.003445 -0.748754  1.000000  0.909636   -0.754728   -0.765946
# poupanca   -0.113406 -0.776432  0.909636  1.000000   -0.775857   -0.784141
# selic_lag1  0.056608  0.884278 -0.754728 -0.775857    1.000000    0.842796
# selic_lag3  0.013198  0.798559 -0.765946 -0.784141    0.842796    1.000000

# %%
X = df_final[["selic_lag1", "selic_lag3", "pib", "poupanca"]]
y = df_final["ipca"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

modelo = LinearRegression()
modelo.fit(X_train, y_train)

modelo.score(X_test, y_test)
# Out:
# 0.06115204454277412

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

plt.plot(df_final["data"], df_final["ipca"], label="IPCA")
plt.plot(df_final["data"], df_final["selic"], label="SELIC")

plt.legend()
plt.title("IPCA vs SELIC")

# salva na pasta imagens
plt.savefig("imagens/grafico_ipca_selic.png")

# mostra no notebook
plt.show()
